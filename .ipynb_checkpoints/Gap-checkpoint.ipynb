# 46       Angola    Africa  2002   41.003  10866106   2773.287312
# 47       Angola    Africa  2007   42.731  12420476   4797.231267
# 48    Argentina  Americas  1952   62.485  17876956   5911.315053
# 49    Argentina  Americas  1957   64.399  19610538   6856.856212
# 50    Argentina  Americas  1962   65.142  21283783   7133.166023
# 51    Argentina  Americas  1967   65.634  22934225   8052.953021
# 52    Argentina  Americas  1972   67.065  24779799   9443.038526
# 53    Argentina  Americas  1977   68.481  26983828  10079.026740
# 54    Argentina  Americas  1982   69.942  29341374   8997.897412
# 55    Argentina  Americas  1987   70.774  31620918   9139.671389
# 56    Argentina  Americas  1992   71.868  33958947   9308.418710
# 57    Argentina  Americas  1997   73.275  36203463  10967.281950
# 58    Argentina  Americas  2002   74.340  38331121   8797.640716
# 59    Argentina  Americas  2007   75.320  40301927  12779.379640

# %%
year=data.sort_values(by=["country","year"])

year.head(20)
# Out:
#         country continent  year  lifeExp       pop    gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333   779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934   820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083   853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966   836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460   739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372   786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816   978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957   852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921   649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415   635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405   726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923   974.580338
# 12      Albania    Europe  1952   55.230   1282697  1601.056136
# 13      Albania    Europe  1957   59.280   1476505  1942.284244
# 14      Albania    Europe  1962   64.820   1728137  2312.888958
# 15      Albania    Europe  1967   66.220   1984060  2760.196931
# 16      Albania    Europe  1972   67.690   2263554  3313.422188
# 17      Albania    Europe  1977   68.930   2509048  3533.003910
# 18      Albania    Europe  1982   70.420   2780097  3630.880722
# 19      Albania    Europe  1987   72.000   3075321  3738.932735

# %%
calcular la mediana de cada pais
# Out:
#   File "<ipython-input-153-04dbc4b3a3df>", line 1
#     calcular la mediana de cada pais
#              ^
# SyntaxError: invalid syntax

# %%
data.shape
# Out:
# (1704, 6)

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Question 1:

# %%
min_data= data[["year","lifeExp"]]  

#print(min_data)

min_data.head(10)
# Out:
#    year  lifeExp
# 0  1952   28.801
# 1  1957   30.332
# 2  1962   31.997
# 3  1967   34.020
# 4  1972   36.088
# 5  1977   38.438
# 6  1982   39.854
# 7  1987   40.822
# 8  1992   41.674
# 9  1997   41.763

# %%
x=min_data["year"]
y=min_data["lifeExp"]
min_data.plot(x="year",y="lifeExp", style="o")
plt.scatter(x,y,s=100,color="blue", edgecolor='black',linewidth=0.5,alpha=0.75)
plt.title('lifeExp vs Years \n', color="black",fontsize=15)
plt.xlabel('lifeExp \n',fontsize=15)
plt.ylabel('Year',fontsize=15)


plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = np.array(min_data["year"]).reshape(-1,1)
y = np.array(min_data["lifeExp"]).reshape(-1,1)

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2)

# %%
regresion= linear_model.LinearRegression()
regresion.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regresion.score(x_train,y_train)) #El score es bajo, por ende la correlación no es significativa.
# Out:
# 0.2039081230099512

# %%
y_pred= regresion.predict(x_test)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred,color="blue",linewidth=3)
plt.title("Linear Regresion \n",color="black",fontsize=15)
plt.colorbar(orientation="vertical")

plt.show()

# %% [markdown]
# ### Question 2:

# %% [markdown]
# Recordar que:
# si las medias y las medianas sos iguales, es una distribución normal.
# Si la media es > que la mediana, aparecen los picos muy finos y alargados.
#
# Es Unimoda ya que no se obervan picos. Es asimétrico a la izquierda, por ende no es simétrico respecto del centro.

# %% [markdown]
# ### Question 3:

# %% [markdown]
# Seguiría rechanzando la hipótesis de no relación ya que no existe una correlación significativamente alta.

# %% [markdown]
# ### Question 4:

# %% [markdown]
#
# La gráfica de violín de residuos se debería ver unimodal y simétrica respecto del centro ya que la correlación debería ser superior al 50%.

# %% [markdown]
# ### Question 5:

# %%
sns.catplot(x="year",y="lifeExp",data=min_data,kind="violin")

plt.show()

# %% [markdown]
# ## Exercise 2:

# %% [markdown]
# ### Question 6:

# %% [markdown]
# La esperanza de vida aumenta 2 años en promedio en el mundo por cada año transcurrido.

# %%
a1 = data[data['year'] == 1952]
a2 = data[data['year'] == 1957]
a3 = data[data['year'] == 1962]
a4 = data[data['year'] == 1967]
a5 = data[data['year'] == 1972]
a6 = data[data['year'] == 1977]
a7 = data[data['year'] == 1982]
a8 = data[data['year'] == 1987]
a9 = data[data['year'] == 1992]
a10 = data[data['year'] == 1997]
a11 = data[data['year'] == 2002]
a12 = data[data['year'] == 2007]

# %%
a=pd.DataFrame([a1["lifeExp"].mean(),a2["lifeExp"].mean(),a3["lifeExp"].mean(),a4["lifeExp"].mean(),a5["lifeExp"].mean(),
  a6["lifeExp"].mean(),a7["lifeExp"].mean(),a8["lifeExp"].mean(),a9["lifeExp"].mean(),a10["lifeExp"].mean(),
  a11["lifeExp"].mean(),a12["lifeExp"].mean()],colum="expLifes")


a.head(12)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-408-daead5e9d075> in <module>
# ----> 1 a=pd.DataFrame([a1["lifeExp"].mean(),a2["lifeExp"].mean(),a3["lifeExp"].mean(),a4["lifeExp"].mean(),a5["lifeExp"].mean(),
#       2   a6["lifeExp"].mean(),a7["lifeExp"].mean(),a8["lifeExp"].mean(),a9["lifeExp"].mean(),a10["lifeExp"].mean(),
#       3   a11["lifeExp"].mean(),a12["lifeExp"].mean()],colum="expLifes")
#       4
#       5
#
# TypeError: __init__() got an unexpected keyword argument 'colum'

# %% [markdown]
# ## Part 2: Classification

# %%
# Generate data for linear regression:
gen_data_x, gen_data_y = sklearn.datasets.make_regression(n_samples=100, n_features=20, noise = 1.5)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-256-e263291c8f0e> in <module>
#       1 # Generate data for linear regression:
# ----> 2 gen_data_x, gen_data_y = sklearn.datasets.make_regression(n_samples=100, n_features=20, noise = 1.5)
#
# NameError: name 'sklearn' is not defined

# %%
# Generate data for logistic regression. This is similar to linear, only now values are either 0 or 1.
log_gen_data_x, dump_y = sklearn.datasets.make_regression(n_samples=100, n_features=20, noise = 1.5)
log_gen_data_y = [0 if i>0 else 1 for i in dump_y]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-257-58366adfd9ad> in <module>
#       1 # Generate data for logistic regression. This is similar to linear, only now values are either 0 or 1.
# ----> 2 log_gen_data_x, dump_y = sklearn.datasets.make_regression(n_samples=100, n_features=20, noise = 1.5)
#       3 log_gen_data_y = [0 if i>0 else 1 for i in dump_y]
#
# NameError: name 'sklearn' is not defined

# %%
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm
plt.rcParams['figure.figsize'] = (16, 9)
plt.style.use('ggplot')

# %%
XY_train = np.array(min_data)
z_train= np.array(data["gdpPercap"])

# %%
# Creamos un nuevo objeto de Regresión Lineal
regr2 = linear_model.LinearRegression()
 
# Entrenamos el modelo, esta vez, con 2 dimensiones
# obtendremos 2 coeficientes, para graficar un plano
regr2.fit(XY_train, z_train)
 
# Hacemos la predicción con la que tendremos puntos sobre el plano hallado
z_pred = regr2.predict(XY_train)
 
# Los coeficientes
print('Coefficients: \n', regr2.coef_)
# Error cuadrático medio
print("Mean squared error: %.2f" % mean_squared_error(z_train, z_pred))
# Evaluamos el puntaje de varianza (siendo 1.0 el mejor posible)
print('Variance score: %.2f' % r2_score(z_train, z_pred))
# Out:
# Coefficients:
#  [-18.99101479 456.5022351 ]
# Mean squared error: 63937880.68
# Variance score: 0.34

# %%
fig = plt.figure()
ax = Axes3D(fig)
 
# Creamos una malla, sobre la cual graficaremos el plano
xx, yy = np.meshgrid(np.linspace(0, 3500, num=10), np.linspace(10, 60, num=10))
 
# calculamos los valores del plano para los puntos x e y
nuevoX = (regr2.coef_[0] * xx)
nuevoY = (regr2.coef_[1] * yy) 
 
# calculamos los correspondientes valores para z. Debemos sumar el punto de intercepción
z = (nuevoX + nuevoY + regr2.intercept_)
 
# Graficamos el plano
ax.plot_surface(xx, yy, z, alpha=0.5, cmap='hot')
 
# Graficamos en azul los puntos en 3D
ax.scatter(XY_train[:, 0], XY_train[:, 1], z_train, c='black',s=60)
 
# Graficamos en rojo, los puntos que 
ax.scatter(XY_train[:, 0], XY_train[:, 1], z_pred, c='red',s=60)
 
# con esto situamos la "camara" con la que visualizamos
ax.view_init(elev=20., azim=60)
        
ax.set_xlabel('lifeExp \n')
ax.set_ylabel('year \n')
ax.set_zlabel('gdpPercap')
ax.set_title('Regresión Lineal con Múltiples Variables')
# Out:
# Text(0.5, 0.92, 'Regresión Lineal con Múltiples Variables')
