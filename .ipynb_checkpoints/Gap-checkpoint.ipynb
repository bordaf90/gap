# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import linear_model
from sklearn.linear_model import LinearRegression
import seaborn as sns

# %%
data = pd.read_csv("gap.tsv", sep='\t')
data.head(60)
# Out:
#         country continent  year  lifeExp       pop     gdpPercap
# 0   Afghanistan      Asia  1952   28.801   8425333    779.445314
# 1   Afghanistan      Asia  1957   30.332   9240934    820.853030
# 2   Afghanistan      Asia  1962   31.997  10267083    853.100710
# 3   Afghanistan      Asia  1967   34.020  11537966    836.197138
# 4   Afghanistan      Asia  1972   36.088  13079460    739.981106
# 5   Afghanistan      Asia  1977   38.438  14880372    786.113360
# 6   Afghanistan      Asia  1982   39.854  12881816    978.011439
# 7   Afghanistan      Asia  1987   40.822  13867957    852.395945
# 8   Afghanistan      Asia  1992   41.674  16317921    649.341395
# 9   Afghanistan      Asia  1997   41.763  22227415    635.341351
# 10  Afghanistan      Asia  2002   42.129  25268405    726.734055
# 11  Afghanistan      Asia  2007   43.828  31889923    974.580338
# 12      Albania    Europe  1952   55.230   1282697   1601.056136
# ...

# %%
year=data.sort_values(by=["year"])

year.head(20)
# Out:
#                  country continent  year  lifeExp        pop    gdpPercap
# 0            Afghanistan      Asia  1952   28.801    8425333   779.445314
# 528               France    Europe  1952   67.410   42459667  7029.809327
# 540                Gabon    Africa  1952   37.003     420702  4293.476475
# 1656  West Bank and Gaza      Asia  1952   43.160    1030585  1515.592329
# 552               Gambia    Africa  1952   30.000     284320   485.230659
# 564              Germany    Europe  1952   67.500   69145952  7144.114393
# 576                Ghana    Africa  1952   43.149    5581001   911.298937
# 588               Greece    Europe  1952   65.860    7733250  3530.690067
# 600            Guatemala  Americas  1952   42.023    3146381  2428.237769
# 612               Guinea    Africa  1952   33.609    2664249   510.196492
# 624        Guinea-Bissau    Africa  1952   32.500     580653   299.850319
# 636                Haiti  Americas  1952   37.579    3201488  1840.366939
# ...

# %%
calcular la mediana de cada pais

# %%
data.shape
# Out:
# (1704, 6)

# %% [markdown]
# ## Exercise 1

# %% [markdown]
# ### Question 1:

# %%
min_data= data[["year","lifeExp"]]  

#print(min_data)

min_data.head(10)
# Out:
#    year  lifeExp
# 0  1952   28.801
# 1  1957   30.332
# 2  1962   31.997
# 3  1967   34.020
# 4  1972   36.088
# 5  1977   38.438
# 6  1982   39.854
# 7  1987   40.822
# 8  1992   41.674
# 9  1997   41.763

# %%
x=min_data["lifeExp"]
y=min_data["year"]
min_data.plot(x="lifeExp",y="year", style="o")
plt.scatter(x,y,s=100, edgecolor='black',linewidth=0.5,alpha=0.75)
plt.title('lifeExp vs Years \n', color="black",fontsize=15)
plt.xlabel('lifeExp \n',fontsize=15)
plt.ylabel('Year',fontsize=15)


plt.show()

# %%
from sklearn.model_selection import train_test_split

# %%
x = np.array(min_data["lifeExp"]).reshape(-1,1)
y = np.array(min_data["year"]).reshape(-1,1)

x_train, x_test, y_train, y_test= train_test_split(x,y, test_size=0.2)

# %%
regresion= linear_model.LinearRegression()
regresion.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
print(regresion.score(x_train,y_train)) #El score es bajo, por ende la correlación no es significativa.
# Out:
# 0.19549198354344544

# %%
y_pred= regresion.predict(x_test)

# %%
plt.scatter(x_train,y_train)
plt.plot(x_test,y_pred,color="red",linewidth=3)
plt.title("Linear Regresion \n",color="black",fontsize=15)
plt.colorbar(orientation="horizontal")

plt.show()

# %% [markdown]
# ### Question 2:

# %% [markdown]
# Recordar que:
# si las medias y las medianas sos iguales, es una distribución normal.
# Si la media es > que la mediana, aparecen los picos muy finos y alargados.
#
# No es Unimodal, es Bimodal, ya que se ven dos picos. Es asimétrico a la izquierda, por ende no es simétrico respecto del centro.
#
# ## Pensar:
#
# ### <font color='red'> son 142 paises y 12 datos de años para cada uno. </font>
#
# ##  <font color='red'> "Para x pais monstrar los 12 datos" </font>

# %%
year.groupby("year").max()
# Out:
#        country continent  lifeExp         pop     gdpPercap
# year
# 1952  Zimbabwe   Oceania   72.670   556263527  108382.35290
# 1957  Zimbabwe   Oceania   73.470   637408000  113523.13290
# 1962  Zimbabwe   Oceania   73.680   665770000   95458.11176
# 1967  Zimbabwe   Oceania   74.160   754550000   80894.88326
# 1972  Zimbabwe   Oceania   74.720   862030000  109347.86700
# 1977  Zimbabwe   Oceania   76.110   943455000   59265.47714
# 1982  Zimbabwe   Oceania   77.110  1000281000   33693.17525
# 1987  Zimbabwe   Oceania   78.670  1084035000   31540.97480
# 1992  Zimbabwe   Oceania   79.360  1164970000   34932.91959
# 1997  Zimbabwe   Oceania   80.690  1230075000   41283.16433
# 2002  Zimbabwe   Oceania   82.000  1280400000   44683.97525
# 2007  Zimbabwe   Oceania   82.603  1318683096   49357.19017

# %%
cant_paises= year["country"].drop_duplicates()

len(cant_paises)
# Out:
# 142

# %%
cant_anios= year["year"].drop_duplicates()

len(cant_anios)
# Out:
# 12

# %%
year.groupby(["country"]).size().reset_index(name="count_years")
# Out:
#                 country  count_years
# 0           Afghanistan           12
# 1               Albania           12
# 2               Algeria           12
# 3                Angola           12
# 4             Argentina           12
# ..                  ...          ...
# 137             Vietnam           12
# 138  West Bank and Gaza           12
# 139         Yemen, Rep.           12
# 140              Zambia           12
# 141            Zimbabwe           12
#
# [142 rows x 2 columns]

# %% [markdown]
# ### Question 3:

# %% [markdown]
# Seguiría rechanzando la hipótesis de no relación ya que no existe una correlación significativamente alta.

# %% [markdown]
# ### Question 4:

# %% [markdown]
# residuo: distancias entre nuestra recta de predichos y las observaciones de la vida real (este concepto no va en el tp)
#
# La gráfica de violín de residuos se debería ver unimodal y simétrica respecto del centro ya que la correlación debería ser superior al 50%.

# %% [markdown]
# ### Question 5:

# %%
sns.set_style('whitegrid')

# %%
anio=data.year.value_counts()

print(anio)
# Out:
# 2007    142
# 2002    142
# 1997    142
# 1992    142
# 1987    142
# 1982    142
# 1977    142
# 1972    142
# 1967    142
# 1962    142
# 1957    142
# 1952    142
# Name: year, dtype: int64

# %%
pais=data.country.value_counts()

print(pais)
# Out:
# Mauritius              12
# Equatorial Guinea      12
# Cote d'Ivoire          12
# Sierra Leone           12
# United States          12
#                        ..
# Senegal                12
# Nigeria                12
# Belgium                12
# Tanzania               12
# Trinidad and Tobago    12
# Name: country, Length: 142, dtype: int64

# %% [markdown]
# ### <font color="red"> Para esto necesito resolver lo del punto 2, para asi poder hacer un gráfico de violín </font>

# %% [markdown]
# ## Exercise 2:

# %% [markdown]
# ### Question 6:
